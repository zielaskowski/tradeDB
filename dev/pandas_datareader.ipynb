# %%
import pandas_datareader as pdr

# %%
f=pdr.DataReader('GOOG','stooq')

# %%
f
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2023-09-22  131.6800  133.0100  130.5100  131.2500  17355284
# 2023-09-21  132.3900  133.1900  131.0900  131.3600  22058375
# 2023-09-20  138.8300  138.8400  134.5200  134.5900  21473533
# 2023-09-19  138.2500  139.1750  137.5000  138.8300  15484644
# 2023-09-18  137.6300  139.9300  137.6300  138.9600  16233590
# ...              ...       ...       ...       ...       ...
# 2018-10-02   59.5480   60.4980   59.3315   60.0055  33758280
# 2018-10-01   59.9945   60.4950   59.5150   59.7655  27152080
# 2018-09-28   59.5935   59.7705   59.2250   59.6735  27612580
# 2018-09-27   59.3365   60.1050   59.1815   59.7320  25215080
# 2018-09-26   59.2575   59.7115   58.7385   59.0245  29245060
#
# [1256 rows x 5 columns]

# %%
pdr.DataReader('GE','yahoo')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 pdr.DataReader('GE','yahoo')
#
# File ~/.backup/venv/tradeDB/lib64/python3.11/site-packages/pandas/util/_decorators.py:213, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     211         raise TypeError(msg)
#     212     kwargs[new_arg_name] = new_arg_value
# --> 213 return func(*args, **kwargs)
#
# File ~/.backup/venv/tradeDB/lib64/python3.11/site-packages/pandas_datareader/data.py:379, in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     367     raise NotImplementedError(msg)
#     369 if data_source == "yahoo":
#     370     return YahooDailyReader(
#     371         symbols=name,
#     372         start=start,
#     373         end=end,
#     374         adjust_price=False,
#     375         chunksize=25,
# ...
