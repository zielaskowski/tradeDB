# %%
# set environment variable 'ALPHAVANTAGE_API_KEY' to your api key
# best would be in /etc/environment
# (don't forget to reload your session, logout/login)
from alpha_vantage.timeseries import TimeSeries as TS
from alpha_vantage.foreignexchange import ForeignExchange as FE
stock = TS()
curr = FE()

# %%
stock.get_symbol_search('GE HEALTHCARE')
# Out:
# (  1. symbol                         2. name 3. type      4. region  \
#  0   L0T.FRK         GE HEALTHCARE TECH.INC.  Equity      Frankfurt
#  1      GEHC  GE HealthCare Technologies Inc  Equity  United States
#
#    5. marketOpen 6. marketClose 7. timezone 8. currency 9. matchScore
#  0         08:00          20:00      UTC+02         EUR        0.7222
#  1         09:30          16:00      UTC-04         USD        0.6047  ,
#  None)

# %%
stock.get_daily_adjusted('GEHC')
# Out:
# ({'2023-07-18': {'1. open': '81.1081',
#    '2. high': '82.895',
#    '3. low': '80.75',
#    '4. close': '82.47',
#    '5. adjusted close': '82.47',
#    '6. volume': '2844487',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-17': {'1. open': '81.74',
#    '2. high': '82.36',
#    '3. low': '81.08',
#    '4. close': '81.19',
#    '5. adjusted close': '81.19',
#    '6. volume': '2343189',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-14': {'1. open': '81.5',
#    '2. high': '82.16',
#    '3. low': '81.23',
#    '4. close': '81.82',
#    '5. adjusted close': '81.82',
#    '6. volume': '1791872',
#    '7. dividend amount': '0.0000',
#    '8. split coefficient': '1.0'},
#   '2023-07-13': {'1. open': '81.73',
#    '2. high': '82.0',
#    '3. low': '80.9',
#    '4. close': '81.4',
#    '5. adjusted close': '81.4',
#    '6. volume': '1476326',
#    '7. dividend amount': '0.0000',
# ...

# %%
curr.get_currency_exchange_rate(from_currency='USD', to_currency='PLN')
# Out:
# ({'1. From_Currency Code': 'USD',
#   '2. From_Currency Name': 'United States Dollar',
#   '3. To_Currency Code': 'PLN',
#   '4. To_Currency Name': 'Polish Zloty',
#   '5. Exchange Rate': '3.98070000',
#   '6. Last Refreshed': '2023-07-19 17:53:40',
#   '7. Time Zone': 'UTC',
#   '8. Bid Price': '3.98062000',
#   '9. Ask Price': '3.98077000'},
#  None)
